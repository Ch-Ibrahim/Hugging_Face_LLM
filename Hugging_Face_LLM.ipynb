# %% [markdown]
# Running Local LLMS

# %%
# pip install huggingface_hub

# %%
import os
from huggingface_hub import hf_hub_download

# %%
huggingface_key=os.environ.get("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")

# %%
model_id="lmsys/fastchat-t5-3b-v1.0"
filename=["pytorch_model.bin" ,
          "added_tokens.json",
          "config.json",
          "generation_config.json",
          "special_tokens_map.json",
          "spiece.model",
          "tokenizer_config.json"]

# %%
for filename in filename:
   downloaded_model_path = hf_hub_download(
      repo_id=model_id, 
      filename=filename, 
      token=huggingface_key)  
   print(downloaded_model_path)
# Out:
# ...
# C:\Users\Dell\.cache\huggingface\hub\models--lmsys--fastchat-t5-3b-v1.0\snapshots\0b1da230a891854102d749b93f7ddf1f18a81024\pytorch_model.bin
# C:\Users\Dell\.cache\huggingface\hub\models--lmsys--fastchat-t5-3b-v1.0\snapshots\0b1da230a891854102d749b93f7ddf1f18a81024\added_tokens.json
# C:\Users\Dell\.cache\huggingface\hub\models--lmsys--fastchat-t5-3b-v1.0\snapshots\0b1da230a891854102d749b93f7ddf1f18a81024\config.json
# C:\Users\Dell\.cache\huggingface\hub\models--lmsys--fastchat-t5-3b-v1.0\snapshots\0b1da230a891854102d749b93f7ddf1f18a81024\generation_config.json
# C:\Users\Dell\.cache\huggingface\hub\models--lmsys--fastchat-t5-3b-v1.0\snapshots\0b1da230a891854102d749b93f7ddf1f18a81024\special_tokens_map.json
# C:\Users\Dell\.cache\huggingface\hub\models--lmsys--fastchat-t5-3b-v1.0\snapshots\0b1da230a891854102d749b93f7ddf1f18a81024\spiece.model
# ...

# %%
import socket
import subprocess
import sys
import time

def check_connectivity(host="8.8.8.8", port=53, timeout=3):
	try:
		socket.setdefaulttimeout(timeout)
		with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
			s.connect((host, port))
		return True
	except Exception:
		return False

def toggle_wifi(off=True, interface_name="Wi-Fi"):
	if sys.platform.startswith("win"):
		state = "disabled" if off else "enabled"
		subprocess.run([
			"netsh", "interface", "set", "interface",
			interface_name, "admin="+state
		], check=False)
	else:
		raise NotImplementedError("Wi-Fi toggle implemented only for Windows in this cell.")

print("Connected (before):", check_connectivity())
# requires elevated permissions on Windows
toggle_wifi(off=True)
time.sleep(0.5)
print("Connected (after):", check_connectivity())
# Out:
# Connected (before): True
# Connected (after): True

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline

tokenizer = AutoTokenizer.from_pretrained(model_id)

model_text = AutoModelForSeq2SeqLM.from_pretrained(model_id)

generator = pipeline(
    'text-generation', 
    model=model_text, 
    device_map=1,
    tokenizer=tokenizer,
    max_length=1000)
# Out:
# Loading weights:   0%|          | 0/560 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# The tied weights mapping and config for this model specifies to tie shared.weight to encoder.embed_tokens.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# The tied weights mapping and config for this model specifies to tie shared.weight to decoder.embed_tokens.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# ...

# %%
generator("I am a student and I want to learn about machine learning. Can you explain it to me?")
# Out:
# [{'generated_text': 'I am a student and I want to learn about machine learning. Can you explain it to me?g algorithms to learn patterns and patterns in data. It is used in a wide range of applications such as image recognition, speech recognition, and natural language processing. Here are the basic concepts of machine learning and how it works (in simple terms) : 1. Data preprocessing - this involves cleaning and transforming the data to prepare it for training a model. 2. Model training - this involves training a model on the data and applying its predictions or outputs to real world data. 3. Model evaluation - this involves evaluating the model on a test set of data to see how well it performs compared to the training data. 4. Model deployment - this involves deploying the model to a production environment and assessing its performance on real data. 5. Model evaluation - this involves evaluating the model on simulation data to see how it performs in a real world scenario. 6. Model 
# ...

# %%
generator("Can you tell me about Algeria country and some beatiful region to visit and what is the right time to explore it")
# Out:
# [{'generated_text': 'Can you tell me about Algeria country and some beatiful region to visit and what is the right time to explore ithe  south,  Libya  to  the  west,  and  the  Mediterranean  coast  to  the  west.  Algeria  is  home  to  many  beautiful  regions  such  as  the  Sahara,  al-Arabian  Desert,  the  Sahara  du  Sahara  region,  the  Mopti  region,  and  the  Sahara  du  Tigris.\n The  Sahara  du  Sahara  is  a  vast  desert  region  located  in  the  Sahara  desert  of  North  Africa.  It  is  famous  for  its  red  sandstone  and  limestone  mountains.\n The  Mopti  region  is  located  on  the  border  between  Algeria  and  Tunisia.  It  is  known  for  its  rugged  landscape  and  the  stunning  beauty  of  its  natural  scenery.\n The  Sahara  du  Tigris  region  is  located  in  the  southwestern  part  of  Algeria.  It  is  famous  for  its  sandy  beaches  and  the  beautiful  scenery  of  its  national  parks.\n The  Tigris  du  Tigris  region  is  located  in 
# ...

# %%
generator("can you give me a python code to implement a simple linear regression model using scikit-learn?")
# Out:
# [{'generated_text': 'can you give me a python code to implement a simple linear regression model using scikit-learn?earn:``` python\n import  pandas  as  pd\n #  Load  your  data\n data  =  pd.read_csv("data.csv")\n #  Preprocess  the  data\n data  =  pd.split("  n")\n #  Fit  the  linear  regression  model  to  the  data\n model  =  pd.linear_regression(data,  data_preprocessing=True)\n #  Evaluate  the  model\n y_fit  =  model.fit(data)\n print(y_fit)``` This  code  loads  the  data  from  a  CSV  file,  preprocesses  it,  and  then  fits  a  simple  linear  regression  model  to  the  data  using  the` pd.linear_regression` method.  The` fit` method  takes  two  arguments:  the  model  to  estimate  and  the  model  to  evaluate.  The  model  estimates  the  mean  of  the  data  and  the  model  evaluates  the  model  by  comparing  the  predicted  values  to  the  actual  values.\n'}]

# %%
generator("What is machine learning? Can you explain it to me in simple terms? and give me fields of application?")
# Out:
# [{'generated_text': 'What is machine learning? Can you explain it to me in simple terms? and give me fields of application?ecisions based on that data. It involves taking large amounts of data and using it to train models to make predictions or identify patterns. There are many fields of applications where machine learning is used such as finance, healthcare, and natural language processing.'}]
